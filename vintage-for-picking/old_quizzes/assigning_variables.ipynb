# %% [markdown]
# # Assigning Variables
#
# ## Learning objectives
#
# After working through this topic, you should be able to:
#
# - Assign variables in Python
# - Do simple manipulations with variables
# - Compare variables
#
# ## Materials
#
# Here is the [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/xxx). These are the
# [slides](python_basics-assigning_variables.pdf).
#
# ## Quiz

# %%
content = [
    {
        "question": 'How can you assign the value 13 to the variable "a" \
            if the variable "a" is currently assigned to the value 8?',
        "type": "many_choice",
        "answers": [
            {
                "answer": ("simply execute a = 13",),
                "correct": True,
                "feedback": "This simply overwrites the value of a",
            },
            {
                "answer": ("First execute a = None, then a = 13",),
                "correct": False,
                "feedback": "While this works, this is not necessary.",
            },
            {
                "answer": ("a = a+5",),
                "correct": False,
                "feedback": "While this works, this is not necessary and \
                    dangerous since executing this cell multiple times will \
                        increase the value of a each time.",
            },
            {
                "answer": ("You cannot assign a new value to a variable.",),
                "correct": False,
                "feedback": "This is not ture.",
            },
        ],
    },
    {
        "question": 'How can you calculate the square of the variable "a"?',
        "type": "many_choice",
        "answers": [
            {
                "answer": (r"a\*a",),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": ("a^2",),
                "correct": False,
                "feedback": "This results in a+2.",
            },
            {
                "answer": (r"a\*\*2",),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": (r"a\*\*a",),
                "correct": False,
                "feedback": "This results in a to the power of a.",
            },
        ],
    },
    {
        "question": "How can you check if two variables are the same?",
        "type": "many_choice",
        "answers": [
            {
                "answer": ("a>b",),
                "correct": False,
                "feedback": "This will return True whenever a is greater than b.",
            },
            {
                "answer": ("a<b",),
                "correct": False,
                "feedback": "This will return True whenever a is smaller than b.",
            },
            {
                "answer": ("a == b",),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": ("a != b",),
                "correct": False,
                "feedback": "This will return False whenever a is equal to b.\
                        While you could use this, this is very confusing.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")

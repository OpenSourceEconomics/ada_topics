# %% [markdown]
# # Pitfalls of Jupyter Notebooks
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
# - Explain why linear execution of cells is important before considering something
#   finished
# - Explain the importance of restarting the kernel
# - Restart the kernel and execute all cells in one go
#
# ## Materials
#
# Here is the [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/xxx).
#
# ## Quiz

# %%
content = [
    {
        "question": "In Jupyter Notebooks, the order in which cells are executed:",
        "type": "many_choice",
        "answers": [
            {
                "answer": (
                    "Is the order in which cells appear on the screen IF you restart \
                        the kernel and select 'run all'",
                ),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": ("Is always random",),
                "correct": False,
                "feedback": "",
            },
            {
                "answer": ("Is determined by which cell you run first",),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": ("Is the order in which cells appear on the screen",),
                "correct": False,
                "feedback": "",
            },
        ],
    },
    {
        "question": "Before considering your work done, you will have to:",
        "type": "many_choice",
        "answers": [
            {
                "answer": (
                    "Check that your code produces the expected output \
                        after restarting the kernel and selecting 'run all'",
                ),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": (
                    "Check that your code produces the expected output \
                        after selecting 'run all'",
                ),
                "correct": False,
                "feedback": "If you don't restart the Kernel, the desired \
                    output could be obtained thanks to previous definition \
                    of variables",
            },
            {
                "answer": (
                    "Run the last cell and make sure it produces \
                           the desired outcome",
                ),
                "correct": False,
                "feedback": "This is not sufficient since the outcome \
                    could be obtained thanks to path specific executions",
            },
            {
                "answer": (
                    "Run the first cell and make sure it produces \
                           the desired outcome",
                ),
                "correct": False,
                "feedback": "The correct execution of the first cell does \
                    not imply the correct functioning of the all code.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")

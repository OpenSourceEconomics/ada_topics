# %% [markdown]
# # Getting started with notebooks
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Start a JupyterHub client from eCampus
# - Execute notebook cells using `Shift-Enter`
# - Restart the kernel
# - Explain why linear execution of cells is important before considering something
#   finished
#
# ## Materials
#
# Here is the
# [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/b29fa066-e381-4ef1-a90d-6cef5baab30f/6e891411-970a-4cca-b7ba-5494d9712291/2f8e0f72-2c92-4f8c-a455-bc92a52cc8ed.mp4).
#
#
# ## Quiz

# %%
content = [
    {
        "question": "Check all boxes that apply.",
        "type": "many_choice",
        "answers": [
            {
                "answer": (
                    "We can do everything that we do on JupyterHub also on our own "
                    "computer if we install some freely available programmes."
                ),
                "correct": True,
                "feedback": (
                    "You are more than welcome to practice that for yourself! Should "
                    "we use data that you are not allowed to download, we will let you"
                    "know."
                ),
            },
            {
                "answer": (
                    "We will get support from the teaching team if running things on "
                    "our own computer."
                ),
                "correct": False,
                "feedback": (
                    "Debugging issues on local machines takes too much time. Apologies."
                ),
            },
            {
                "answer": (
                    "We will get support from the teaching team if running things on "
                    "JupyterHub."
                ),
                "correct": True,
                "feedback": (
                    "Still, please try for a reasonable amount of time yourselves and "
                    "check with your peers.",
                ),
            },
            {
                "answer": (
                    "JupyterHub is the only way to run the Python code required in "
                    "this course."
                ),
                "correct": False,
                "feedback": (
                    "You can freely install Python and run code, that is why it is the "
                    "most popular language for data analytics."
                ),
            },
        ],
    },
    {
        "question": "The preferred way to execute a single notebook cell is...",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": (
                    "by clicking on the 'play' button in the top row of the notebook "
                    "tab"
                ),
                "correct": False,
                "feedback": "This takes nearly forever.",
            },
            {
                "answer": ("Selecting the cell and pressing 'Shift' + 'Enter'."),
                "correct": True,
                "feedback": (
                    "Indeed, this is by far the quickest way. Practice this and other "
                    "keyboard shortcuts."
                ),
            },
            {
                "answer": (
                    "by selecting 'Run' from the menu bar and then 'Run Selected Cell' "
                    "from the drop-down menu."
                ),
                "correct": False,
                "feedback": ("This takes forever."),
            },
            {
                "answer": (
                    "by selecting 'Run' from the menu bar and then 'Restart kernel and "
                    "run all cells' from the drop-down menu."
                ),
                "correct": False,
                "feedback": (
                    "This will run all cells. You will want to do that every now and "
                    "then. And at the very end for sure. But not to run a single cell."
                ),
            },
            {
                "answer": (
                    "by clicking on the 'fast-forward' button in the top row of the "
                    "notebook tab"
                ),
                "correct": False,
                "feedback": (
                    "This will run all cells. You will want to do that every now and "
                    "then. And at the very end for sure. But not to run a single cell."
                ),
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")

# %% [markdown]
# # Assignment and Built-in Scalar Types
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - List several built-in scalar types in Python
# - Assign and manipulate scalar variables in Python
# - Convert variables between different types
#
# ## Materials
#
# Here is the
# [screencast](https://player.uni-bonn.educast.nrw/6aa0b00c-298f-48d9-a9ad-afc5ccb865ac)
# and these are the [slides](python_basics-assignment_and_scalar_types.pdf).
#
# ## Additional Materials
#
# - [Documentation](https://docs.python.org/3/library/stdtypes.html) of Python built-in types
#
#
# ## Quiz

# %%
from jupyterquiz import display_quiz

content = [
    {
        "question": (
            "If you need to represent a real number, in Python you would use ..."
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "A float", "correct": True, "feedback": "Correct."},
            {"answer": "An integer", "correct": False, "feedback": "Incorrect."},
            {"answer": "A Boolean", "correct": False, "feedback": "Incorrect."},
        ],
    },
    {
        "question": ("Which of the following are properties about floats?"),
        "type": "many_choice",
        "answers": [
            {
                "answer": "They can represent arbitrarily large numbers",
                "correct": False,
                "feedback": "False.",
            },
            {
                "answer": "They can be used for scientific calculations",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "They can be added to integers",
                "correct": True,
                "feedback": "Correct",
            },
            {
                "answer": "The can represent any real number in a given interval",
                "correct": False,
                "feedback": "Incorrect.",
            },
        ],
    },
    {
        "question": ("Which values can a Boolean take?"),
        "type": "many_choice",
        "answers": [
            {"answer": "true", "correct": False, "feedback": "False."},
            {"answer": "false", "correct": False, "feedback": "Incorrect."},
            {"answer": "True", "correct": True, "feedback": "Correct."},
            {"answer": "False", "correct": True, "feedback": "Correct"},
        ],
    },
    {
        "question": "What do you expect the following code to produce?",
        "code": "True == 1.0",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "True",
                "correct": True,
                "feedback": (
                    "Indeed, the Boolean is converted to a float (1.0) on the fly and "
                    "then compared."
                ),
            },
            {
                "answer": "true",
                "correct": False,
                "feedback": "Watch the capitalisation!",
            },
            {"answer": "False", "correct": False, "feedback": "Incorrect."},
            {
                "answer": (
                    "An error stating that it is not possible to compare Booleans "
                    "and floats"
                ),
                "correct": False,
                "feedback": "The Boolean will be converted to a float implicitly.",
            },
        ],
    },
    {
        "question": "What is the result of the following operation?",
        "code": "(True + False + True)?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "True",
                "correct": False,
                "feedback": (
                    "Incorrect. Booleans are converted to integers upon addition."
                ),
            },
            {
                "answer": "Booleans cannot be added to each other.",
                "correct": False,
                "feedback": "Incorrect.",
            },
            {
                "answer": "2",
                "correct": True,
                "feedback": (
                    "Correct. Booleans are converted to int objects when included in "
                    "addition operations (True = 1, False = 0)."
                ),
            },
            {
                "answer": "3",
                "correct": False,
                "feedback": (
                    "When converting Booleans to ints, False is converted to 0."
                ),
            },
        ],
    },
]
display_quiz(content, colors="fdsp")

# %% [markdown]
# # Measures of Central Tendency
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Provide an example of cardinal data
# - Compute measures of central tendency for a given data set (mean, median, mode).
# - Be aware of the potential limitations of each measure given the context of the data.
#
# ## Materials
#
# Here is [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/xxx). These are the
# [slides](descriptive_statistics-central_tendency_cardinal_data.pdf).
#
# ## Quiz

# %%
content = [
    {
        "question": "What is the definition of the mean?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": (
                    "The mean is the sum of the values divided by the number of values."
                ),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": (
                    "The mean is the middle value when the values are sorted in "
                ),
                "correct": False,
                "feedback": "",
            },
            {
                "answer": (
                    "The mean is the value that occurs most frequently in the data."
                ),
                "correct": False,
                "feedback": "",
            },
        ],
    },
    {
        "question": "What is the main pitfall of using the mean?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The mean is sensitive to outliers.",
                "correct": True,
                "feedback": "",
            },
            {
                "answer": "The mean is difficult to calculate.",
                "correct": False,
                "feedback": "",
            },
            {
                "answer": "The mean is not a measure of central tendency.",
                "correct": False,
                "feedback": "",
            },
        ],
    },
    {
        "question": "What is the median?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """The median is the middle value when the values are sorted
                in ascending order.""",
                "correct": True,
                "feedback": "",
            },
            {
                "answer": """The median is the sum of the values divided by the number
                of values.""",
                "correct": False,
                "feedback": "",
            },
            {
                "answer": """The median is the value that occurs most frequently in the
                data.""",
                "correct": False,
                "feedback": "",
            },
        ],
    },
    {
        "question": "What is the median of the following data set: 1, 2, 3, 4?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "2.5",
                "correct": True,
                "feedback": "",
            },
            {
                "answer": "2",
                "correct": False,
                "feedback": """Remember: the median for an even number of values is the
                average of the two middle values.""",
            },
            {
                "answer": "3",
                "correct": False,
                "feedback": """Remember: the median for an even number of values is the
                average of the two middle values.""",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
